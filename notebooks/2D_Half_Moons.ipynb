# %% [markdown]
# # **0. Intro**

# %%
# to display all the outputs
#from IPython.core.interactiveshell import InteractiveShell
#InteractiveShell.ast_node_interactivity = "all"

from google.colab import drive
drive.mount('/content/drive')
import sys
nb_path = "/content/drive/My Drive/NeuralODE/Media"
if nb_path not in sys.path:
  sys.path.insert(5, nb_path)

# !wget -O mini.sh https://repo.anaconda.com/miniconda/Miniconda3-py38_4.8.2-Linux-x86_64.sh
# !chmod +x mini.sh
# !bash ./mini.sh -b -f -p /usr/local
# !conda install -q -y --prefix /usr/local jupyter
# !python -m ipykernel install --name "py38" --user

# !pip install git+https://github.com/DiffEqML/torchdyn.git
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# --2022-02-28 11:36:38--  https://repo.anaconda.com/miniconda/Miniconda3-py38_4.8.2-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.130.3, 104.16.131.3, 2606:4700::6810:8303, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.130.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 89817099 (86M) [application/x-sh]
# Saving to: ‘mini.sh’
#
# mini.sh             100%[===================>]  85.66M   176MB/s    in 0.5s
#
# 2022-02-28 11:36:39 (176 MB/s) - ‘mini.sh’ saved [89817099/89817099]
#
# PREFIX=/usr/local
# Unpacking payload ...
# done
# /
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/noarch::prompt-toolkit==3.0.20=pyhd3eb1b0_0
#   - defaults/noarch::prometheus_client==0.13.1=pyhd3eb1b0_0
#   - defaults/noarch::jinja2==3.0.2=pyhd3eb1b0_0
#   - defaults/linux-64::terminado==0.13.1=py38h06a4308_0
#   - defaults/linux-64::conda==4.11.0=py38h06a4308_0
#   - defaults/linux-64::glib==2.69.1=h4ff587b_1
#   - defaults/linux-64::sqlite==3.31.1=h7b6447c_0
#   - defaults/linux-64::openssl==1.1.1m=h7f8727e_0
#   - defaults/noarch::pandocfilters==1.5.0=pyhd3eb1b0_0
#   - defaults/linux-64::freetype==2.11.0=h70c0345_0
#   - defaults/linux-64::widgetsnbextension==3.5.2=py38h06a4308_0
#   - defaults/noarch::qtpy==1.11.2=pyhd3eb1b0_0
#   - defaults/linux-64::dbus==1.13.18=hb2f20db_0
#   - defaults/noarch::qtconsole==5.2.2=pyhd3eb1b0_0
#   - defaults/linux-64::six==1.14.0=py38_0
#   - defaults/linux-64::sip==4.19.13=py38h295c915_0
#   - defaults/noarch::traitlets==5.1.1=pyhd3eb1b0_0
#   - defaults/linux-64::cryptography==2.8=py38h1ba5d50_0
#   - defaults/linux-64::requests==2.22.0=py38_1
#   - defaults/linux-64::jupyter_core==4.9.1=py38h06a4308_0
#   - defaults/linux-64::markupsafe==2.0.1=py38h27cfd23_0
#   - defaults/linux-64::expat==2.4.4=h295c915_0
#   - defaults/linux-64::notebook==6.4.8=py38h06a4308_0
#   - defaults/linux-64::jedi==0.18.1=py38h06a4308_1
#   - defaults/linux-64::pip==20.0.2=py38_1
#   - defaults/noarch::importlib_metadata==4.8.2=hd3eb1b0_0
#   - defaults/noarch::nbclient==0.5.11=pyhd3eb1b0_0
#   - defaults/noarch::pygments==2.11.2=pyhd3eb1b0_0
#   - defaults/noarch::attrs==21.4.0=pyhd3eb1b0_0
#   - defaults/noarch::python-dateutil==2.8.2=pyhd3eb1b0_0
#   - defaults/linux-64::ruamel_yaml==0.15.87=py38h7b6447c_0
#   - defaults/noarch::jupyterlab_pygments==0.1.2=py_0
#   - defaults/linux-64::tk==8.6.8=hbc83047_0
#   - defaults/linux-64::importlib-metadata==4.8.2=py38h06a4308_0
#   - defaults/linux-64::argon2-cffi-bindings==21.2.0=py38h7f8727e_0
#   - defaults/linux-64::pyzmq==22.3.0=py38h295c915_2
#   - defaults/noarch::packaging==21.3=pyhd3eb1b0_0
#   - defaults/noarch::pickleshare==0.7.5=pyhd3eb1b0_1003
#   - defaults/linux-64::pyopenssl==19.1.0=py38_0
#   - defaults/linux-64::qt==5.9.7=h5867ecd_1
#   - defaults/linux-64::zlib==1.2.11=h7b6447c_3
#   - defaults/linux-64::cffi==1.14.0=py38h2e261b9_0
#   - defaults/linux-64::jpeg==9d=h7f8727e_0
#   - defaults/noarch::typing_extensions==3.10.0.2=pyh06a4308_0
#   - defaults/noarch::wcwidth==0.2.5=pyhd3eb1b0_0
#   - defaults/linux-64::idna==2.8=py38_1000
#   - defaults/linux-64::libuuid==1.0.3=h7f8727e_2
#   - defaults/linux-64::pcre==8.45=h295c915_0
#   - defaults/linux-64::setuptools==45.2.0=py38_0
#   - defaults/linux-64::libxml2==2.9.12=h03d6c58_0
#   - defaults/linux-64::chardet==3.0.4=py38_1003
#   - defaults/linux-64::conda-package-handling==1.6.0=py38h7b6447c_0
#   - defaults/noarch::matplotlib-inline==0.1.2=pyhd3eb1b0_2
#   - defaults/noarch::backcall==0.2.0=pyhd3eb1b0_0
#   - defaults/linux-64::libsodium==1.0.18=h7b6447c_0
#   - defaults/linux-64::wheel==0.34.2=py38_0
#   - defaults/noarch::argon2-cffi==21.3.0=pyhd3eb1b0_0
#   - defaults/linux-64::mistune==0.8.4=py38h7b6447c_1000
#   - defaults/linux-64::fontconfig==2.13.1=h6c09931_0
#   - defaults/linux-64::readline==7.0=h7b6447c_5
#   - defaults/linux-64::gst-plugins-base==1.14.0=h8213a91_2
#   - defaults/linux-64::pycosat==0.6.3=py38h7b6447c_0
#   - defaults/noarch::zipp==3.7.0=pyhd3eb1b0_0
#   - defaults/linux-64::tornado==6.1=py38h27cfd23_0
#   - defaults/noarch::prompt_toolkit==3.0.20=hd3eb1b0_0
#   - defaults/noarch::tqdm==4.42.1=py_0
#   - defaults/linux-64::ipython==7.31.1=py38h06a4308_0
#   - defaults/linux-64::libxcb==1.14=h7b6447c_0
#   - defaults/linux-64::pyqt==5.9.2=py38h05f1152_4
#   - defaults/linux-64::python==3.8.1=h0371630_1
#   - defaults/noarch::ipywidgets==7.6.5=pyhd3eb1b0_1
#   - defaults/noarch::defusedxml==0.7.1=pyhd3eb1b0_0
#   - defaults/noarch::pyparsing==3.0.4=pyhd3eb1b0_0
#   - defaults/noarch::testpath==0.5.0=pyhd3eb1b0_0
#   - defaults/linux-64::jupyter==1.0.0=py38_7
#   - defaults/noarch::bleach==4.1.0=pyhd3eb1b0_0
#   - defaults/noarch::typing-extensions==3.10.0.2=hd3eb1b0_0
#   - defaults/noarch::jupyter_console==6.4.0=pyhd3eb1b0_0
#   - defaults/linux-64::webencodings==0.5.1=py38_1
#   - defaults/noarch::send2trash==1.8.0=pyhd3eb1b0_1
#   - defaults/noarch::nbformat==5.1.3=pyhd3eb1b0_0
#   - defaults/linux-64::pysocks==1.7.1=py38_0
#   - defaults/noarch::jsonschema==3.2.0=pyhd3eb1b0_2
#   - defaults/linux-64::libpng==1.6.37=hbc83047_0
#   - defaults/noarch::decorator==5.1.1=pyhd3eb1b0_0
#   - defaults/linux-64::zeromq==4.3.4=h2531618_0
#   - defaults/linux-64::icu==58.2=he6710b0_3
#   - defaults/noarch::nest-asyncio==1.5.1=pyhd3eb1b0_0
#   - defaults/linux-64::certifi==2021.10.8=py38h06a4308_2
#   - defaults/linux-64::entrypoints==0.3=py38_0
#   - defaults/linux-64::ipykernel==6.4.1=py38h06a4308_1
#   - defaults/linux-64::yaml==0.1.7=had09818_2
#   - defaults/linux-64::pyrsistent==0.18.0=py38heee7806_0
#   - defaults/noarch::ipython_genutils==0.2.0=pyhd3eb1b0_1
#   - defaults/noarch::ptyprocess==0.7.0=pyhd3eb1b0_2
#   - defaults/noarch::jupyterlab_widgets==1.0.0=pyhd3eb1b0_1
#   - defaults/linux-64::ncurses==6.2=he6710b0_0
#   - defaults/noarch::pexpect==4.8.0=pyhd3eb1b0_3
#   - defaults/noarch::jupyter_client==7.1.2=pyhd3eb1b0_0
#   - defaults/linux-64::nbconvert==6.3.0=py38h06a4308_0
#   - defaults/linux-64::xz==5.2.5=h7b6447c_0
#   - defaults/linux-64::urllib3==1.25.8=py38_0
#   - defaults/linux-64::libffi==3.3=he6710b0_2
#   - defaults/linux-64::libgcc-ng==9.3.0=h5101ec6_17
#   - defaults/linux-64::gstreamer==1.14.0=h28cd5cc_2
#   - defaults/linux-64::asn1crypto==1.3.0=py38_0
#   - defaults/linux-64::libedit==3.1.20181209=hc058e9b_0
#   - defaults/linux-64::debugpy==1.5.1=py38h295c915_0
#   - defaults/noarch::parso==0.8.3=pyhd3eb1b0_0
#   - defaults/noarch::pycparser==2.19=py_0
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _libgcc_mutex==0.1=main
#     - asn1crypto==1.3.0=py38_0
#     - ca-certificates==2020.1.1=0
#     - certifi==2019.11.28=py38_0
#     - cffi==1.14.0=py38h2e261b9_0
#     - chardet==3.0.4=py38_1003
#     - conda-package-handling==1.6.0=py38h7b6447c_0
#     - conda==4.8.2=py38_0
#     - cryptography==2.8=py38h1ba5d50_0
#     - idna==2.8=py38_1000
#     - ld_impl_linux-64==2.33.1=h53a641e_7
#     - libedit==3.1.20181209=hc058e9b_0
#     - libffi==3.2.1=hd88cf55_4
#     - libgcc-ng==9.1.0=hdf63c60_0
#     - libstdcxx-ng==9.1.0=hdf63c60_0
#     - ncurses==6.2=he6710b0_0
#     - openssl==1.1.1d=h7b6447c_4
#     - pip==20.0.2=py38_1
#     - pycosat==0.6.3=py38h7b6447c_0
#     - pycparser==2.19=py_0
#     - pyopenssl==19.1.0=py38_0
#     - pysocks==1.7.1=py38_0
#     - python==3.8.1=h0371630_1
#     - readline==7.0=h7b6447c_5
#     - requests==2.22.0=py38_1
#     - ruamel_yaml==0.15.87=py38h7b6447c_0
#     - setuptools==45.2.0=py38_0
#     - six==1.14.0=py38_0
#     - sqlite==3.31.1=h7b6447c_0
#     - tk==8.6.8=hbc83047_0
#     - tqdm==4.42.1=py_0
#     - urllib3==1.25.8=py38_0
#     - wheel==0.34.2=py38_0
#     - xz==5.2.4=h14c3975_4
#     - yaml==0.1.7=had09818_2
#     - zlib==1.2.11=h7b6447c_3
#
#
# The following packages will be DOWNGRADED:
#
#   ca-certificates                     2021.10.26-h06a4308_2 --> 2020.1.1-0
#
#
# done
# done
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniconda3.
#     For best results, please verify that your PYTHONPATH only points to
#     directories of packages that are compatible with the Python interpreter
#     in Miniconda3: /usr/local
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - jupyter
#
#
# The following packages will be UPDATED:
#
#   ca-certificates                                2020.1.1-0 --> 2021.10.26-h06a4308_2
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Installed kernelspec py38 in /root/.local/share/jupyter/kernels/py38
# Collecting git+https://github.com/DiffEqML/torchdyn.git
#   Cloning https://github.com/DiffEqML/torchdyn.git to /tmp/pip-req-build-5se06yyv
#   Running command git clone -q https://github.com/DiffEqML/torchdyn.git /tmp/pip-req-build-5se06yyv
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied (use --upgrade to upgrade): torchdyn==1.0.1 from git+https://github.com/DiffEqML/torchdyn.git in /usr/local/lib/python3.8/site-packages
# Requirement already satisfied: poethepoet<0.11.0,>=0.10.0 in /usr/local/lib/python3.8/site-packages (from torchdyn==1.0.1) (0.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/site-packages (from torchdyn==1.0.1) (1.8.0)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.8/site-packages (from torchdyn==1.0.1) (0.11.3)
# Requirement already satisfied: sklearn in /usr/local/lib/python3.8/site-packages (from torchdyn==1.0.1) (0.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.8/site-packages (from torchdyn==1.0.1) (3.5.1)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.8/site-packages (from torchdyn==1.0.1) (7.6.5)
# Requirement already satisfied: torchcde<0.3.0,>=0.2.3 in /usr/local/lib/python3.8/site-packages (from torchdyn==1.0.1) (0.2.5)
# Requirement already satisfied: pytorch-lightning in /usr/local/lib/python3.8/site-packages (from torchdyn==1.0.1) (1.5.10)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.8/site-packages (from torchdyn==1.0.1) (6.4.1)
# Requirement already satisfied: torch<2.0.0,>=1.8.1 in /usr/local/lib/python3.8/site-packages (from torchdyn==1.0.1) (1.10.2)
# Requirement already satisfied: torchsde in /usr/local/lib/python3.8/site-packages (from torchdyn==1.0.1) (0.2.5)
# Requirement already satisfied: tomlkit<1.0.0,>=0.6.0 in /usr/local/lib/python3.8/site-packages (from poethepoet<0.11.0,>=0.10.0->torchdyn==1.0.1) (0.10.0)
# Requirement already satisfied: pastel<0.3.0,>=0.2.0 in /usr/local/lib/python3.8/site-packages (from poethepoet<0.11.0,>=0.10.0->torchdyn==1.0.1) (0.2.1)
# Requirement already satisfied: numpy<1.25.0,>=1.17.3 in /usr/local/lib/python3.8/site-packages (from scipy->torchdyn==1.0.1) (1.22.2)
# Requirement already satisfied: pillow!=8.3.0,>=5.3.0 in /usr/local/lib/python3.8/site-packages (from torchvision->torchdyn==1.0.1) (9.0.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.8/site-packages (from sklearn->torchdyn==1.0.1) (1.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/site-packages (from matplotlib->torchdyn==1.0.1) (21.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/site-packages (from matplotlib->torchdyn==1.0.1) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/site-packages (from matplotlib->torchdyn==1.0.1) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.8/site-packages (from matplotlib->torchdyn==1.0.1) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.8/site-packages (from matplotlib->torchdyn==1.0.1) (4.29.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.8/site-packages (from matplotlib->torchdyn==1.0.1) (3.0.4)
# Requirement already satisfied: nbformat>=4.2.0 in /usr/local/lib/python3.8/site-packages (from ipywidgets->torchdyn==1.0.1) (5.1.3)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.8/site-packages (from ipywidgets->torchdyn==1.0.1) (5.1.1)
# Requirement already satisfied: ipython>=4.0.0; python_version >= "3.3" in /usr/local/lib/python3.8/site-packages (from ipywidgets->torchdyn==1.0.1) (7.31.1)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /usr/local/lib/python3.8/site-packages (from ipywidgets->torchdyn==1.0.1) (3.5.2)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0; python_version >= "3.6" in /usr/local/lib/python3.8/site-packages (from ipywidgets->torchdyn==1.0.1) (1.0.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.8/site-packages (from ipywidgets->torchdyn==1.0.1) (0.2.0)
# Requirement already satisfied: torchdiffeq>=0.2.0 in /usr/local/lib/python3.8/site-packages (from torchcde<0.3.0,>=0.2.3->torchdyn==1.0.1) (0.2.2)
# Requirement already satisfied: future>=0.17.1 in /usr/local/lib/python3.8/site-packages (from pytorch-lightning->torchdyn==1.0.1) (0.18.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/site-packages (from pytorch-lightning->torchdyn==1.0.1) (3.10.0.2)
# Requirement already satisfied: tensorboard>=2.2.0 in /usr/local/lib/python3.8/site-packages (from pytorch-lightning->torchdyn==1.0.1) (2.8.0)
# Requirement already satisfied: fsspec[http]!=2021.06.0,>=2021.05.0 in /usr/local/lib/python3.8/site-packages (from pytorch-lightning->torchdyn==1.0.1) (2022.2.0)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.8/site-packages (from pytorch-lightning->torchdyn==1.0.1) (4.42.1)
# Requirement already satisfied: setuptools==59.5.0 in /usr/local/lib/python3.8/site-packages (from pytorch-lightning->torchdyn==1.0.1) (59.5.0)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.8/site-packages (from pytorch-lightning->torchdyn==1.0.1) (6.0)
# Requirement already satisfied: pyDeprecate==0.3.1 in /usr/local/lib/python3.8/site-packages (from pytorch-lightning->torchdyn==1.0.1) (0.3.1)
# Requirement already satisfied: torchmetrics>=0.4.1 in /usr/local/lib/python3.8/site-packages (from pytorch-lightning->torchdyn==1.0.1) (0.7.2)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /usr/local/lib/python3.8/site-packages (from ipykernel->torchdyn==1.0.1) (1.5.1)
# Requirement already satisfied: jupyter-client<8.0 in /usr/local/lib/python3.8/site-packages (from ipykernel->torchdyn==1.0.1) (7.1.2)
# Requirement already satisfied: tornado<7.0,>=4.2 in /usr/local/lib/python3.8/site-packages (from ipykernel->torchdyn==1.0.1) (6.1)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in /usr/local/lib/python3.8/site-packages (from ipykernel->torchdyn==1.0.1) (0.1.2)
# Requirement already satisfied: boltons>=20.2.1 in /usr/local/lib/python3.8/site-packages (from torchsde->torchdyn==1.0.1) (21.0.0)
# Requirement already satisfied: trampoline>=0.1.2 in /usr/local/lib/python3.8/site-packages (from torchsde->torchdyn==1.0.1) (0.1.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/site-packages (from scikit-learn->sklearn->torchdyn==1.0.1) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/site-packages (from scikit-learn->sklearn->torchdyn==1.0.1) (1.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib->torchdyn==1.0.1) (1.14.0)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.8/site-packages (from nbformat>=4.2.0->ipywidgets->torchdyn==1.0.1) (4.9.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /usr/local/lib/python3.8/site-packages (from nbformat>=4.2.0->ipywidgets->torchdyn==1.0.1) (3.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.8/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets->torchdyn==1.0.1) (3.0.20)
# Requirement already satisfied: decorator in /usr/local/lib/python3.8/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets->torchdyn==1.0.1) (5.1.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.8/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets->torchdyn==1.0.1) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.8/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets->torchdyn==1.0.1) (0.18.1)
# Requirement already satisfied: pygments in /usr/local/lib/python3.8/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets->torchdyn==1.0.1) (2.11.2)
# Requirement already satisfied: pexpect>4.3; sys_platform != "win32" in /usr/local/lib/python3.8/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets->torchdyn==1.0.1) (4.8.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.8/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets->torchdyn==1.0.1) (0.7.5)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.8/site-packages (from widgetsnbextension~=3.5.0->ipywidgets->torchdyn==1.0.1) (6.4.8)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.8/site-packages (from tensorboard>=2.2.0->pytorch-lightning->torchdyn==1.0.1) (3.3.6)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.8/site-packages (from tensorboard>=2.2.0->pytorch-lightning->torchdyn==1.0.1) (1.0.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.8/site-packages (from tensorboard>=2.2.0->pytorch-lightning->torchdyn==1.0.1) (2.6.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.8/site-packages (from tensorboard>=2.2.0->pytorch-lightning->torchdyn==1.0.1) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.8/site-packages (from tensorboard>=2.2.0->pytorch-lightning->torchdyn==1.0.1) (0.4.6)
# Requirement already satisfied: protobuf>=3.6.0 in /usr/local/lib/python3.8/site-packages (from tensorboard>=2.2.0->pytorch-lightning->torchdyn==1.0.1) (3.19.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.8/site-packages (from tensorboard>=2.2.0->pytorch-lightning->torchdyn==1.0.1) (2.22.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.8/site-packages (from tensorboard>=2.2.0->pytorch-lightning->torchdyn==1.0.1) (0.34.2)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.8/site-packages (from tensorboard>=2.2.0->pytorch-lightning->torchdyn==1.0.1) (2.0.3)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.8/site-packages (from tensorboard>=2.2.0->pytorch-lightning->torchdyn==1.0.1) (1.44.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.8/site-packages (from tensorboard>=2.2.0->pytorch-lightning->torchdyn==1.0.1) (1.8.1)
# Requirement already satisfied: aiohttp; extra == "http" in /usr/local/lib/python3.8/site-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning->torchdyn==1.0.1) (3.8.1)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.8/site-packages (from jupyter-client<8.0->ipykernel->torchdyn==1.0.1) (0.3)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.8/site-packages (from jupyter-client<8.0->ipykernel->torchdyn==1.0.1) (1.5.1)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.8/site-packages (from jupyter-client<8.0->ipykernel->torchdyn==1.0.1) (22.3.0)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->torchdyn==1.0.1) (21.4.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /usr/local/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->torchdyn==1.0.1) (0.18.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0; python_version >= "3.3"->ipywidgets->torchdyn==1.0.1) (0.2.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.8/site-packages (from jedi>=0.16->ipython>=4.0.0; python_version >= "3.3"->ipywidgets->torchdyn==1.0.1) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.8/site-packages (from pexpect>4.3; sys_platform != "win32"->ipython>=4.0.0; python_version >= "3.3"->ipywidgets->torchdyn==1.0.1) (0.7.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->torchdyn==1.0.1) (1.8.0)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->torchdyn==1.0.1) (21.3.0)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->torchdyn==1.0.1) (6.3.0)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->torchdyn==1.0.1) (0.13.1)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->torchdyn==1.0.1) (0.13.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->torchdyn==1.0.1) (3.0.2)
# Requirement already satisfied: importlib-metadata>=4.4; python_version < "3.10" in /usr/local/lib/python3.8/site-packages (from markdown>=2.6.8->tensorboard>=2.2.0->pytorch-lightning->torchdyn==1.0.1) (4.8.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning->torchdyn==1.0.1) (5.0.0)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in /usr/local/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning->torchdyn==1.0.1) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning->torchdyn==1.0.1) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.8/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning->torchdyn==1.0.1) (1.3.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard>=2.2.0->pytorch-lightning->torchdyn==1.0.1) (2021.10.8)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard>=2.2.0->pytorch-lightning->torchdyn==1.0.1) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard>=2.2.0->pytorch-lightning->torchdyn==1.0.1) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard>=2.2.0->pytorch-lightning->torchdyn==1.0.1) (1.25.8)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.8/site-packages (from aiohttp; extra == "http"->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning->torchdyn==1.0.1) (4.0.2)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.8/site-packages (from aiohttp; extra == "http"->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning->torchdyn==1.0.1) (2.0.12)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.8/site-packages (from aiohttp; extra == "http"->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning->torchdyn==1.0.1) (1.7.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.8/site-packages (from aiohttp; extra == "http"->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning->torchdyn==1.0.1) (1.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.8/site-packages (from aiohttp; extra == "http"->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning->torchdyn==1.0.1) (1.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.8/site-packages (from aiohttp; extra == "http"->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning->torchdyn==1.0.1) (6.0.2)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.8/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->torchdyn==1.0.1) (21.2.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->torchdyn==1.0.1) (0.8.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->torchdyn==1.0.1) (0.1.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->torchdyn==1.0.1) (1.5.0)
# Requirement already satisfied: testpath in /usr/local/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->torchdyn==1.0.1) (0.5.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->torchdyn==1.0.1) (0.7.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /usr/local/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->torchdyn==1.0.1) (0.5.11)
# Requirement already satisfied: bleach in /usr/local/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->torchdyn==1.0.1) (4.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.8/site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->torchdyn==1.0.1) (2.0.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/site-packages (from importlib-metadata>=4.4; python_version < "3.10"->markdown>=2.6.8->tensorboard>=2.2.0->pytorch-lightning->torchdyn==1.0.1) (3.7.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.8/site-packages (from rsa<5,>=3.1.4; python_version >= "3.6"->google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning->torchdyn==1.0.1) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning->torchdyn==1.0.1) (3.2.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.8/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->torchdyn==1.0.1) (1.14.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.8/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->torchdyn==1.0.1) (0.5.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.8/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->torchdyn==1.0.1) (2.19)
# Building wheels for collected packages: torchdyn
#   Building wheel for torchdyn (PEP 517) ... done
#   Created wheel for torchdyn: filename=torchdyn-1.0.1-py3-none-any.whl size=56286 sha256=92882463a8b776cbaa37e4fa4ea92aaa584095bc31374d739e86a77c1cf44cab
#   Stored in directory: /tmp/pip-ephem-wheel-cache-jks4pcc_/wheels/94/6a/38/50e9572d53c98db6aa90249559ce4c087ee548ac8861a3ed58
# Successfully built torchdyn

# %% [markdown]
# # **1. Libraries**

# %%
sys.path.append('/usr/local/lib/python3.8/site-packages/')

import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

from torchdyn.core import NeuralODE
from torchdyn.datasets import *
from torchdyn import *

import torch
import torch.utils.data as data

import torch.nn as nn
import pytorch_lightning as pl

import os

# %load_ext autoreload
# %autoreload 2
# quick run for automated notebook validation
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # **2. Parameters**

# %%
# Parameters
dry_run = False

# %% [markdown]
# # **3. Dataset**

# %%
d = ToyDataset()
X, yn = d.generate(n_samples=512, noise=1e-1, dataset_type='moons')
import matplotlib.pyplot as plt

colors = ['orange', 'blue'];
fig = plt.figure(figsize=(3,3));
ax = fig.add_subplot(111);
for i in range(len(X)):
    ax.scatter(X[i,0], X[i,1], s=1, color=colors[yn[i].int()]);

# %% [markdown]
# # **4. Transform Dataset**

# %%
device = torch.device("cpu") # all of this works in GPU as well :)

X_train = torch.Tensor(X).to(device)
y_train = torch.LongTensor(yn.long()).to(device)
train = data.TensorDataset(X_train, y_train)
trainloader = data.DataLoader(train, batch_size=len(X), shuffle=True)

import torch.nn as nn
import pytorch_lightning as pl

class Learner(pl.LightningModule):
    def __init__(self, t_span:torch.Tensor, model:nn.Module):
        super().__init__()
        self.model, self.t_span = model, t_span

    def forward(self, x):
        return self.model(x)

    def training_step(self, batch, batch_idx):
        x, y = batch
        t_eval, y_hat = self.model(x, t_span)
        y_hat = y_hat[-1] # select last point of solution trajectory
        loss = nn.CrossEntropyLoss()(y_hat, y)
        return {'loss': loss}

    def configure_optimizers(self):
        return torch.optim.Adam(self.model.parameters(), lr=0.01)

    def train_dataloader(self):
        return trainloader

# %% [markdown]
# # **5. Training**

# %%
t_span = torch.linspace(0,1,50)

f = nn.Sequential(
        nn.Linear(2, 64),
        nn.Tanh(),
        nn.Linear(64, 2)
    )

model = NeuralODE(f, sensitivity='adjoint', solver='rk4', solver_adjoint='dopri5', atol_adjoint=1e-4, rtol_adjoint=1e-4).to(device)
learn = Learner(t_span, model)

if dry_run: trainer = pl.Trainer(min_epochs=100, max_epochs=100)
else: trainer = pl.Trainer(min_epochs=300, max_epochs=800)
trainer.fit(learn)
print(learn)
print("------")
print(model)
# Out:
# GPU available: True, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# /usr/local/lib/python3.8/site-packages/pytorch_lightning/trainer/trainer.py:1585: UserWarning: GPU available but not used. Set the gpus flag in your trainer `Trainer(gpus=1)` or script `--gpus=1`.
#   "GPU available but not used. Set the gpus flag in your trainer `Trainer(gpus=1)` or script `--gpus=1`."
#
#   | Name  | Type      | Params
# ------------------------------------
# 0 | model | NeuralODE | 322
# ------------------------------------
# 322       Trainable params
# 0         Non-trainable params
# 322       Total params
# 0.001     Total estimated model params size (MB)
# Your vector field callable (nn.Module) should have both time `t` and state `x` as arguments, we've wrapped it for you.
# /usr/local/lib/python3.8/site-packages/pytorch_lightning/trainer/data_loading.py:433: UserWarning: The number of training samples (1) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#   f"The number of training samples ({self.num_training_batches}) is smaller than the logging interval"
# Training: 0it [00:00, ?it/s]
# Learner(
#   (model): Neural ODE:
#   	- order: 1
#   	- solver: RungeKutta4()
#   	- adjoint solver: DormandPrince45()
#   	- tolerances: relative 0.001 absolute 0.001
#   	- adjoint tolerances: relative 0.0001 absolute 0.0001
#   	- num_parameters: 322
#   	- NFE: 510400.0
# )
# ------
# Neural ODE:
# 	- order: 1
# 	- solver: RungeKutta4()
# 	- adjoint solver: DormandPrince45()
# 	- tolerances: relative 0.001 absolute 0.001
# 	- adjoint tolerances: relative 0.0001 absolute 0.0001
# 	- num_parameters: 322
# 	- NFE: 510400.0

# %% [markdown]
# # **6. Plot**

# %%
t_eval, trajectory = model(X_train, t_span)
trajectory = trajectory.detach().cpu()
color=['orange', 'blue']

fig = plt.figure(figsize=(10,2));
ax0 = fig.add_subplot(121);
ax1 = fig.add_subplot(122);
for i in range(500):
    ax0.plot(t_span, trajectory[:,i,0], color=color[int(yn[i])], alpha=.1);
    ax1.plot(t_span, trajectory[:,i,1], color=color[int(yn[i])], alpha=.1);

ax0.set_xlabel(r"$t$ [Depth]") ; ax0.set_ylabel(r"$h_0(t)$");
ax1.set_xlabel(r"$t$ [Depth]") ; ax1.set_ylabel(r"$z_1(t)$");
ax0.set_title("Dimension 0") ; ax1.set_title("Dimension 1");

# %%
colors = ['orange', 'blue'];
fig = plt.figure(figsize=(3,3));
ax = fig.add_subplot(111);

j=49
for i in range(500):
  ax.scatter(trajectory[j,i,0], trajectory[j,i,1], s=1, color=colors[yn[i].int()]);

# %%
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt

plt.ioff()
colors = ['orange', 'blue']
fig = plt.figure(figsize = (10, 7))
ax = plt.axes(projection ="3d")

for i in range(len(X)):
  ax.view_init(30)
  ax.scatter3D(t_eval.detach().numpy(), trajectory[:,i,0], trajectory[:,i,1], s=3, color=colors[yn[i].int()])

# %%
# Evaluate vector field
n_pts = 10
x = torch.linspace(trajectory[:,:,0].min(), trajectory[:,:,0].max(), n_pts)
y = torch.linspace(trajectory[:,:,1].min(), trajectory[:,:,1].max(), n_pts)
XX, YY = torch.meshgrid(x, y)
z = torch.cat([XX.reshape(-1,1), YY.reshape(-1,1)], 1)
t_eval_f, trajectory_f = model(z, t_span)

derivative = trajectory_f
dt = t_eval[1] - t_eval[0]
for i in range(len(t_eval)-1):
    derivative[i] = (trajectory_f[i+1, :, :] - trajectory_f[i, :, :]) / dt

derivative = derivative.detach().numpy()
z = z.detach().numpy()

try:
  os.mkdir(os.path.join(nb_path, "semilune"))
except Exception as e:
  print("Folder already exists")

plt.ioff()
colors = ['orange', 'blue']
for j in range(len(t_span)):
  fig = plt.figure(figsize=(5,5))
  ax = fig.add_subplot(111)
  for i in range(len(z)):
    ax.quiver(z[i, 0], z[i, 1], derivative[j, i, 0], derivative[j, i, 1], color='black', alpha = 0.2)
  for i in range(len(X)):
    ax.scatter(trajectory[j,i,0], trajectory[j,i,1], s=30, color=colors[yn[i].int()])
  fig.savefig(os.path.join(nb_path, "semilune", "semilune_" + str(j)) , dpi=150)
  plt.close(fig)
# Out:
# Folder already exists
